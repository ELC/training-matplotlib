# %% [markdown]
# <div style='text-align:center' >
#     <h1>
#         Bars Charts and Histograms
#     </h1>
#     <h3>
#         [Source](https://www.youtube.com/watch?v=ZyTO4SwhSeE)
#     </h3>
# </div>
#
# <h2><div style="float:left; text-align:left; width:*;line-height: 150%">
# Previous Part:<br>[Legends titles and labels](Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb)
# </div>
# <div style="float:right; text-align:right; width:*;line-height: 150%">
# Next Part:<br>[Scatter Plots](Matplotlib Tutorial Part 04 - Scatter Plots.ipynb)
# </div>
# <div style='margin: 0 auto; text-align:center; width:190px;line-height: 150%' >
# [Table of Contents](Table of Contents.ipynb)
# </div></h2>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar Chart

# %%
fig = plt.figure(figsize=(17,9))

X = [1,5,8,2,4,6,8]
Y = [1,8,2,4,8,9,3]

plt.bar(X,Y, label="Bar")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Multiple Bars Chart

# %%
fig = plt.figure(figsize=(17,9))
X = [1,0,8,1,4,6,8]
Y = [1,8,2,4,8,9,3]

X2 = [1,3,5,9,11]
Y2 = [8,7,1,6,1]

plt.bar(X,Y, label="Bar1")
plt.bar(X2,Y2, label="Bar2")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Adding different Colours

# %%
fig = plt.figure(figsize=(17,9))
X = [1,0,8,3,4]
Y = [1,8,2,4,8]

X2 = [1,0,8,3,4]
Y2 = [9,7,1,6,1]

plt.bar(X,Y, label="Bar1", color='r')
plt.bar(X2,Y2, label="Bar2", color='c')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Swapping order

# %%
fig = plt.figure(figsize=(17,9))
X = [1,0,8,3,4]
Y = [1,8,2,4,8]

X2 = [1,0,8,3,4]
Y2 = [9,7,1,6,1]

plt.bar(X2,Y2, label="Bar2", color='c')
plt.bar(X,Y, label="Bar1", color='r')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Histogram vs Bar Charts

# %%
from random import randint

fig = plt.figure(figsize=(17,9))

X = [randint(0,110) for i in range(100)]
Y = [x for x in range(len(X))]

plt.bar(X,Y, label="Bar", color='r')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

fig = plt.figure(figsize=(17,9))

bins = [i for i in range(0,max(X),10)]
plt.hist(X,bins,histtype='bar',rwidth = 0.8)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Histogram')
plt.show()

# %% [markdown]
# <h2><div style="float:left; text-align:left; width:*;line-height: 150%">
# Previous Part:<br>[Legends titles and labels](Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb)
# </div>
# <div style="float:right; text-align:right; width:*;line-height: 150%">
# Next Part:<br>[Scatter Plots](Matplotlib Tutorial Part 04 - Scatter Plots.ipynb)
# </div>
# <div style='margin: 0 auto; text-align:center; width:190px;line-height: 150%' >
# [Table of Contents](Table of Contents.ipynb)
# </div></h2>
