# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left"><br><br></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb" >Legends titles and labels</a></span>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <h1><center>Matplotlib Tutorial Part 01: Introduction and Line</center></h1>

# %% [markdown]
# ## Source
# This notebook was created by **Ezequiel Castaño** and the materials and idea of the tutorial was inspired and based on the **Sentdex** original tutorial series. Here is the source video

# %%
# %%HTML
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/q7Bo_J8x_dw"></iframe>
# </center>
# Out:
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/q7Bo_J8x_dw"></iframe>
# </center>

# %% [markdown]
# # Necessary Imports

# %%
from random import randint
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Plotting Lines based on points

# %%
X = [1, 2, 3]
Y = [5, 6, 1]

#Plotting and Customization
fig = plt.figure(figsize=(17, 9))
plt.grid(True)
plt.plot(X, Y)
plt.show()

# %% [markdown]
# ## Plotting Points

# %%
X = [1, 2, 3, 4, 9, 3, 7, 1, 2, 8, 5]
Y = [5, 6, 1, 1, 4, 7, 5, 4, 6, 8, 2]

#Plotting and Customization
plt.figure(figsize=(17, 9))
plt.grid(True)
plt.plot(X, Y, '.')
plt.show()

# %% [markdown]
# ## Plotting Math Functions

# %%
def f(x):
    return x**2

X = [i for i in range(-10, 11)]
Y = [f(x) for x in X]

#Plotting and Customization
plt.figure(figsize=(17, 9))
plt.grid(True)
plt.plot(X, Y)
plt.show()

# %% [markdown]
# ## Plotting Random points

# %%
amount_points = 30

X = [i for i in range(amount_points)]
Y = [randint(0, 9) for i in range(amount_points)]

#Plotting and Customization
plt.figure(figsize=(17, 9))
plt.grid(True)
plt.plot(X, Y, '.')
plt.show()

# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left"><br><br></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb" >Legends titles and labels</a></span>
# </div>
# <br>
# <br>
# <br>
