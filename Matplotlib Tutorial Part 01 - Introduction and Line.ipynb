# %% [markdown]
# <div style='text-align:center'>
#     <h1>
#         Introduction and Line
#     </h1>
#     <h3>
#         <a href="https://www.youtube.com/watch?v=q7Bo_J8x_dw">Source</a>
#     </h3>
# </div>
#
# <h2><div style="float:right; text-align:right; width:*;line-height: 150%">
# Next Part:<br><a href="Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb">Legends titles and labels</a>
# </div>
# <div style='margin: 0 auto; text-align:center; width:190px;line-height: 150%' >
# <a href="Table of Contents.ipynb">Table of Contents</a>
# </div></h2>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from random import randint

# %% [markdown]
# ## Plotting Lines based on points

# %%
fig = plt.figure(figsize=(17,9))
X = [1,2,3]
Y = [5,6,1]

#Plotting and Customization
plt.grid(True)
plt.plot(X, Y)
plt.show()

# %% [markdown]
# ## Plotting Points

# %%
fig = plt.figure(figsize=(17,9))
X = [1,2,3,4,9,3,7,1,2,8,5]
Y = [5,6,1,1,4,7,5,4,6,8,2]

#Plotting and Customization
plt.grid(True)
plt.plot(X, Y,'.')
plt.show()

# %% [markdown]
# ## Plotting Math Functions

# %%
fig = plt.figure(figsize=(17,9))
def f(x):
    return x**2

X = [i for i in range(-10,11)]
Y = [f(x) for x in X]

#Plotting and Customization
plt.grid(True)
plt.plot(X,Y)
plt.show()

# %% [markdown]
# ## Plotting Random points

# %%
fig = plt.figure(figsize=(17,9))

amount_points = 30

X = [i for i in range(amount_points)]
Y = [randint(0,9) for i in range(amount_points)]

#Plotting and Customization
plt.grid(True)
plt.plot(X,Y,'.')
plt.show()

# %% [markdown]
# <h2><div style="float:right; text-align:right; width:*;line-height: 150%">
# Next Part:<br><a href="Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb">Legends titles and labels</a>
# </div>
# <div style='margin: 0 auto; text-align:center; width:190px;line-height: 150%' >
# <a href="Table of Contents.ipynb">Table of Contents</a>
# </div></h2>
