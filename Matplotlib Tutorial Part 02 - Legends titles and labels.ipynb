# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 01 - Introduction and Line.ipynb" >Introduction and Line</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 03 - Bar Charts and Histograms.ipynb" >Bar Charts and Histograms</a></span>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <h1><center>Matplotlib Tutorial Part 02: Legends titles and labels</center></h1>

# %% [markdown]
# ## Source
# This notebook was created by **Ezequiel Castaño** and the materials and idea of the tutorial was inspired and based on the **Sentdex** original tutorial series. Here is the source video

# %%
# %%HTML
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/aCULcv_IQYw"></iframe>
# </center>
# Out:
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/aCULcv_IQYw"></iframe>
# </center>

# %% [markdown]
# # Necessary Imports

# %%
from random import randint
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## One Line Graph

# %%
X = [1, 2, 3]
Y = [5, 6, 1]

plt.figure(figsize=(17, 9))
plt.plot(X, Y, label='Graph')

plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Function\nOr Graph')

# Plotting
plt.grid(True)
plt.show()

# %% [markdown]
# ## Data Generation Function

# %%
def generate_data(x=10, ran=9):
    raw = [randint(0, ran) for _ in range(x)]
    return range(len(raw)), raw

# %%
X, Y = generate_data(ran=5)

plt.figure(figsize=(17, 9))
plt.plot(X, Y, label='Graph')

plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Function\nOr Graph')

# Plotting
plt.grid(True)
plt.show()

# %% [markdown]
# ## Several Line Graph on the same box

# %%
plt.figure(figsize=(17, 9))

X, Y = generate_data(ran=5)
plt.plot(X, Y, label='Graph1')

X, Y = generate_data(ran=20)
plt.plot(X, Y, label='Graph2')

X, Y = generate_data()
plt.plot(X, Y, label='Graph3')

# Labels
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Function\nOr Graph')
plt.legend()

# Plotting
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 01 - Introduction and Line.ipynb" >Introduction and Line</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 03 - Bar Charts and Histograms.ipynb" >Bar Charts and Histograms</a></span>
# </div>
# <br>
# <br>
# <br>
