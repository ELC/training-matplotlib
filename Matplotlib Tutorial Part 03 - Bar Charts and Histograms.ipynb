# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb" >Legends titles and labels</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 85%;">Next:<br><br><a href="Matplotlib Tutorial Part 04 - Scatter Plots.ipynb" >Scatter Plots</a></span>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <h1><center>Matplotlib Tutorial Part 03 - Bar Charts and Histograms</center></h1>

# %% [markdown]
# ## Source
# This notebook was created by **Ezequiel Castaño** and the materials and idea of the tutorial was inspired and based on the **Sentdex** original tutorial series. Here is the source video

# %%
# %%HTML
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/ZyTO4SwhSeE"></iframe>
# </center>
# Out:
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/ZyTO4SwhSeE"></iframe>
# </center>

# %% [markdown]
# # Necessary Imports

# %%
from random import randint
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Bar Chart

# %%
X = [1, 5, 8, 2, 4, 6, 8]
Y = [1, 8, 2, 4, 8, 9, 3]

plt.figure(figsize=(17, 9))
plt.bar(X, Y, label="Bar")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Multiple Bars Chart

# %%
X = [1, 0, 8, 1, 4, 6, 8]
Y = [1, 8, 2, 4, 8, 9, 3]

X2 = [1, 3, 5, 9, 11]
Y2 = [8, 7, 1, 6, 1]

plt.figure(figsize=(17, 9))
plt.bar(X, Y, label="Bar1")
plt.bar(X2, Y2, label="Bar2")

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Adding different Colours

# %%
X = [1, 0, 8, 3, 4]
Y = [1, 8, 2, 4, 8]

X2 = [1, 0, 8, 3, 4]
Y2 = [9, 7, 1, 6, 1]

plt.figure(figsize=(17, 9))
plt.bar(X, Y, label="Bar1", color='r')
plt.bar(X2, Y2, label="Bar2", color='c')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.legend()

plt.show()

# %% [markdown]
# ## Histogram vs Bar Charts

# %%
number_of_points = 700
max_value = 20
min_value = 0
number_of_bins = 11

X = [i for i in range(number_of_points)]
Y = [randint(min_value, max_value) for _ in range(number_of_points)]

plt.figure(figsize=(17, 9))
plt.bar(X, Y)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Bar Chart')
plt.show()

bins = np.arange(max_value + 2) - 0.5

plt.figure(figsize=(17, 9))
plt.hist(Y, bins, histtype='bar', rwidth=0.7)

plt.xlabel('x')
plt.xticks(bins[:-1] + 0.5)  # Center the ticks
plt.ylabel('y')
plt.title('Histogram')
plt.show()

# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 02 - Legends titles and labels.ipynb" >Legends titles and labels</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 85%;">Next:<br><br><a href="Matplotlib Tutorial Part 04 - Scatter Plots.ipynb" >Scatter Plots</a></span>
# </div>
# <br>
# <br>
# <br>
