# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 04 - Scatter Plots.ipynb">Scatter Plots</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 88%;">Next:<br><br><a href="Matplotlib Tutorial Part 06 - Pie Charts.ipynb">Pie Charts</a></span>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <h1><center>Matplotlib Tutorial Part 05 - Stack Plots</center></h1>

# %% [markdown]
# ## Source
# This notebook was created by **Ezequiel Castaño** and the materials and idea of the tutorial was inspired and based on the **Sentdex** original tutorial series. Here is the source video

# %%
# %%HTML
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/Z81JW1NTsO8"></iframe>
# </center>
# Out:
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/Z81JW1NTsO8"></iframe>
# </center>

# %% [markdown]
# # Necessary Imports

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
fig = plt.figure(figsize=(17, 9))
# X Axis
days = [1, 2, 3, 4, 5]

# Data
sleeping = [7, 8, 6, 11, 7]
eating = [2, 3, 4, 3, 2]
working = [7, 8, 7, 2, 2]
playing = [8, 5, 7, 8, 13]

# Labels
plt.plot([], [], color='m', label='Sleeping', linewidth=5)
plt.plot([], [], color='c', label='Eating', linewidth=5)
plt.plot([], [], color='r', label='Working', linewidth=5)
plt.plot([], [], color='k', label='Playing', linewidth=5)

# Stack Plot
plt.stackplot(days, sleeping, eating, working,
              playing, colors=['m', 'c', 'r', 'k'])

# Plotting
plt.xlabel('x')
plt.ylabel('y')
plt.title('Stack Plots')
plt.legend()

plt.show()

# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 04 - Scatter Plots.ipynb">Scatter Plots</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 88%;">Next:<br><br><a href="Matplotlib Tutorial Part 06 - Pie Charts.ipynb">Pie Charts</a></span>
# </div>
# <br>
# <br>
# <br>
