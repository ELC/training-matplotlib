# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 05 - Stack Plots.ipynb">Stack Plots</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 07 - Loading Data from Files.ipynb">Loading Data from Files</a></span>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <h1><center>Matplotlib Tutorial Part 06 - Pie Charts</center></h1>

# %% [markdown]
# ## Source
# This notebook was created by **Ezequiel Castaño** and the materials and idea of the tutorial was inspired and based on the **Sentdex** original tutorial series. Here is the source video

# %%
# %%HTML
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/Oh2Dkkswy30"></iframe>
# </center>
# Out:
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/Oh2Dkkswy30"></iframe>
# </center>

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Values
slices = [7, 2, 2, 13]

# Labels
activities = ['sleeping', 'eating', 'working', 'playing']

plt.figure(figsize=(9, 9))
plt.pie(slices, labels=activities,)

plt.title('Pie Chart')

plt.show()

# %% [markdown]
# # Pie Chart Customized

# %%
# Values
slices = [7, 2, 2, 13]

# Labels
activities = ['sleeping', 'eating', 'working', 'playing']

plt.figure(figsize=(9, 9))
plt.pie(slices,
        labels=activities,
        startangle=90,  # Angle
        shadow=True,  # Shadow
        explode=(0.05, 0.05, 0.05, 0.05),  # Separation
        autopct="%1.1f%%")  # Show %

plt.title('Pie Chart')

plt.show()

# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 05 - Stack Plots.ipynb">Stack Plots</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 07 - Loading Data from Files.ipynb">Loading Data from Files</a></span>
# </div>
# <br>
# <br>
# <br>
