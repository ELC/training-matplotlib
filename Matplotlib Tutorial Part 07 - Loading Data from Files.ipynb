# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 06 - Pie Charts.ipynb">Pie Charts</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 08 - Loading Data from Internet.ipynb">Loading Data from Internet</a></span>
# </div>
# <br>
# <br>
# <br>

# %% [markdown]
# <h1><center>Matplotlib Tutorial Part 07 - Loading Data from Files</center></h1>

# %% [markdown]
# ## Source
# This notebook was created by **Ezequiel Castaño** and the materials and idea of the tutorial was inspired and based on the **Sentdex** original tutorial series. Here is the source video

# %%
# %%HTML
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/QyhqzaMiFxk"></iframe>
# </center>
# Out:
# <center>
# <iframe width="960" height="540" frameborder="0" allowfullscreen src="https://www.youtube.com/embed/QyhqzaMiFxk"></iframe>
# </center>

# %% [markdown]
# # Necessary Imports

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

filename = "Matplotlib Tutorial Part 07 - Data"

# %% [markdown]
# ## CSV Method

# %%
with open(filename) as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    X, Y = zip(*plots)

X = [int(i) for i in X]
Y = [int(i) for i in Y]

plt.figure(figsize=(17, 9))
plt.plot(X, Y)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Data loaded with CSV Method')

# Pottling
plt.grid(True)
plt.show()

# %% [markdown]
# ## Numpy Method

# %%
X, Y = np.loadtxt(filename, delimiter=',', unpack=True)

plt.figure(figsize=(17, 9))
plt.plot(X, Y)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Data loaded with Numpy Method')

# Plotting
plt.grid(True)
plt.show()

# %% [markdown]
# <div style="width:100%; font-size:16pt; font-weight:bold;">
#     <span style="position: absolute;top: 0;left: 10%; text-align:left">Previous:<br><br><a href="Matplotlib Tutorial Part 06 - Pie Charts.ipynb">Pie Charts</a></span>
#     <span style="position: absolute;top: 30%;left: 45%;"><a href="Table of Contents.ipynb" >Table of Contents</a></span>
#     <span style="position: absolute;top: 0; text-align:right; left: 75%;">Next:<br><br><a href="Matplotlib Tutorial Part 08 - Loading Data from Internet.ipynb">Loading Data from Internet</a></span>
# </div>
# <br>
# <br>
# <br>
