# %% [markdown]
# # Matplotlib Tutorial Part 13 - Live Graph

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
filename = 'Matplotlib Tutorial Part 13 - Data'

# %% [markdown]
# ## Animation

# %%
fig = plt.figure(figsize=(17,9))

ax1 = plt.subplot2grid((1,1),(0,0))

# Get Data
def animate(i):
    raw_data = open(filename,'r').read()
    lines = raw_data.split('\n')
    selected_lines = (line.split(',') for line in lines if len(line) > 1)
    xs, ys = zip(*selected_lines)
    ax1.clear()
    ax1.plot(xs,ys)

# Animate
ani = animation.FuncAnimation(fig, animate, interval=1000)
plt.show()

# %% [markdown]
# ### Previous Part: [Styles](Matplotlib Tutorial Part 12 - Styles.ipynb)
#
# ### Next Part: [Annotations and Placing Text](Matplotlib Tutorial Part 14 - Annotations and Placing Text.ipynb)
#
# ### [Table of Contents](Table of Contents.ipynb)
